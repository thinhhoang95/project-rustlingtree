# %% [markdown]
# # HLLRD Report
#
# Regenerate summary tables and plots for a fitted model.

# %%
from pathlib import Path
from hllrd.cli import report_main

report_main([
    '--model', '../../data/hllrd/se_model.npz',
    '--matrix', '../../data/hllrd/se_matrix.npz',
    '--output-dir', '../../data/hllrd/report',
])

# %%
import json

summary = json.loads(Path('../../data/hllrd/report/summary.json').read_text())
summary['K'], summary['explained_fraction']
