# %%
import arinc424

# %%
arinc424.parse("SUSAP KDFWK4DHRPER35      020DBLSSK4EA0E       TF                                                                          703231602")
# Out:
# +--------------------------------------------+----------+---------------------------------------------------------+
# | Field                                      | Value    | Decoded                                                 |
# +--------------------------------------------+----------+---------------------------------------------------------+
# | Record Type                                | 'S'      | Standard                                                |
# | Customer / Area Code                       | 'USA'    | United States of America                                |
# | Section Code                               | 'PD'     | Airport SID                                             |
# | Airport Identifier                         | 'KDFW'   | KDFW                                                    |
# | ICAO Code                                  | 'K4'     | K4                                                      |
# ...
